# %%
import thunder as td

# %%
import matplotlib.pyplot as plt
from showit import image,tile

# %%
data=td.images.fromexample('fish')
data
# Out:
# Images
# mode: local
# dtype: uint8
# shape: (20, 2, 76, 87)

# %%
tile(data[0]);

# %%
projections = data.max_projection(axis=0)
projections[0]
# Out:
# Images
# mode: local
# dtype: uint8
# shape: (1, 76, 87)

# %%
# %matplotlib inline

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.3/281.3 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:02
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 3.5 MB/s eta 0:00:000:00:01
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764010 sha256=b336ea77df21f60e5f7974423bf6cecc70f0133ae5850983dea1292242515a44
#   Stored in directory: /home/vu/.cache/pip/wheels/1d/27/68/1382001655ef41217e1dd34d59aa777612135379bab64279e9
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark import SparkContext,SparkConf

# %%
conf=SparkConf().setAppName("sample_app")
sc=SparkContext.getOrCreate();

# %%
sc
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>

# %%
Im=Image.open("download.png")
print(Im.mode,Im.size,Im.format)
display(Im)
# Out:
# RGB (248, 354) JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=248x354>

# %%
pip install --upgrate Pillow
# Out:
# Usage:
#   /home/vu/jupyter/enviroment/bin/python -m pip install [options] <requirement specifier> [package-index-options] ...
#   /home/vu/jupyter/enviroment/bin/python -m pip install [options] -r <requirements file> [package-index-options] ...
#   /home/vu/jupyter/enviroment/bin/python -m pip install [options] [-e] <vcs project url> ...
#   /home/vu/jupyter/enviroment/bin/python -m pip install [options] [-e] <local project path> ...
#   /home/vu/jupyter/enviroment/bin/python -m pip install [options] <archive url/path> ...
#
# no such option: --upgrate
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in ./enviroment/lib/python3.8/site-packages (9.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
h,w=np.asarray(projections[0]).shape
data=np.zeros((h,w,3),dtype=np.uint8)
for i in range(3):
    data[:,:,i]=np.array(projections[0])
Im2= Image.fromarray(data,'RGB')
Im2= Im2.resize(Im.size)
print(Im2.mode,Im2.size,Im2.format)
display(Im2)
# Out:
# RGB (248, 354) None
# <PIL.Image.Image image mode=RGB size=248x354>

# %%
import numpy as np

# %%
Img=Image.blend(Im,Im2,0.5)

# %%
fig,ax = plt.subplots()
plt.imshow(Img)
plt.show()

# %%
colors = ["red","green","blue"]
channel_ids=(0,1,2)
img_arr=np.asarray(Img)
img_reshape=img_arr[np.newaxis,...]
plt.figure()
plt.xlim([0,256])
for channel_id,c in zip(channel_ids,colors):
    histogram,bin_edges=np.histogram(img_reshape[:,:,channel_id],bins=256,range = (0,256))
    plt.plot(bin_edges[0:-1],histogram,color=c)
plt.title("Color Histogram")
plt.xlabel("Color Value")
plt.ylabel("Pixel Count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
